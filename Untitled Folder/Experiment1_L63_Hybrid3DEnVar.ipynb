# %%
# %matplotlib inline
import pickle
import numpy as np
import matplotlib.pyplot as plt

from model import lorenz63_fdm
from assimilation import Hybrid3DEnVar

# %%
X_nature = np.load('./data/X_nature.npy')
X_ini = np.load('./data/X_ini.npy')
ts = np.load('./data/time_span.npy')
Pb = np.load('./data/Pb.npy')
R = np.load('./data/R.npy')

# %%
dt = 0.01

# %%
# generate initial ensemble
N_ens = 30
rng = np.random.RandomState(42)
X_ens_ini = rng.multivariate_normal(X_ini.ravel(), Pb, size=N_ens).T  # (3, N_ens)

# %%
def RMSE(forecast, nature):
    return np.sqrt(np.mean((forecast-nature)**2, axis=0))

# %% [markdown]
# # Assimilate normal observation

# %% [markdown]
# #### `rmse_hy` as CNTL in the later experiments

# %%
# normal observation
X_obs = np.load('./data/obs_normal.npy')

# %%
hy = Hybrid3DEnVar(lorenz63_fdm, dt)
hy.list_params()
params = {
    'X_ini': X_ini,
    'X_ens_ini': X_ens_ini,
    'obs': X_obs,
    'obs_interv': 8,
    'Pb': Pb,
    'R': R,
    'H_func': lambda arr: arr,
    'H': np.eye(3),
    'alpha': 0.3,
    'inflat': 1.4,
    'beta': 0.7
}
hy.set_params(**params)
hy.cycle()

# %%
rmse_hy = RMSE(hy.analysis_3dvar, X_nature)

plt.figure(figsize=(10, 5))
plt.plot(ts, rmse_hy)
plt.ylim([-0.2, 10])
print(rmse_hy.mean())
# Out:
# 0.8495597416751757

# %% [markdown]
# # First moment

# %% [markdown]
# ### Assimilate bias observations based on normality test

# %%
# first moment
ex_obs_dict = pickle.load(open('./data/obs_bias_005_040.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.05', '0.15', '0.20', '0.25', '0.30', '0.35', '0.40'])

# %%
plt.figure(figsize=(12, 6))

mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

for obsm in ex_obs_dict.keys():
    obs = ex_obs_dict[obsm]

    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'obsm={obsm}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=obsm)
    
plt.plot(ts, rmse_hy, 'k', label='CNTL')
plt.legend()
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse')
plt.ylim([-0.2, 10]);
# Out:
# obsm=0.05, Mean RMSE=0.8836, Variance RMSE=0.4184,  Without spinup: Mean RMSE=0.8421, Variance RMSE=0.3149
# obsm=0.15, Mean RMSE=0.8590, Variance RMSE=0.5607,  Without spinup: Mean RMSE=0.7841, Variance RMSE=0.3680
# obsm=0.20, Mean RMSE=0.9294, Variance RMSE=0.5188,  Without spinup: Mean RMSE=0.8717, Variance RMSE=0.3580
# obsm=0.25, Mean RMSE=0.8132, Variance RMSE=0.4524,  Without spinup: Mean RMSE=0.7395, Variance RMSE=0.2530
# obsm=0.30, Mean RMSE=0.9310, Variance RMSE=0.4763,  Without spinup: Mean RMSE=0.8639, Variance RMSE=0.2887
# obsm=0.35, Mean RMSE=0.9477, Variance RMSE=0.5996,  Without spinup: Mean RMSE=0.8871, Variance RMSE=0.4395
# obsm=0.40, Mean RMSE=1.0902, Variance RMSE=0.9933,  Without spinup: Mean RMSE=1.0340, Variance RMSE=0.8841

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_mean = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_mean, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_mean, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_mean, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_mean, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Assimilate more extreme bias observations

# %%
ex_obs_dict = pickle.load(open('./data/obs_bias_020_520.pickle', 'rb'))

# %%
import matplotlib.cm as cm


mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))
colors = cm.GnBu(np.linspace(0, 1, len(ex_obs_dict.keys())))

for obsm, color in zip(ex_obs_dict.keys(), colors):
    obs = ex_obs_dict[obsm]

    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'obsm={obsm}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())
    
    plt.plot(ts, rmse, color=color, label=obsm)
    
# CNTL
plt.plot(ts, rmse_hy, color='k', label='CNTL')

# no DA
forecast = lorenz63_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('RMSE');
# Out:
# obsm=0.20, Mean RMSE=0.9017, Variance RMSE=0.4424,  Without spinup: Mean RMSE=0.8410, Variance RMSE=0.2771
# obsm=0.45, Mean RMSE=1.0861, Variance RMSE=1.2313,  Without spinup: Mean RMSE=1.0504, Variance RMSE=1.1475
# obsm=0.70, Mean RMSE=1.3949, Variance RMSE=2.1056,  Without spinup: Mean RMSE=1.3279, Variance RMSE=2.0039
# obsm=0.95, Mean RMSE=1.3897, Variance RMSE=1.3480,  Without spinup: Mean RMSE=1.3265, Variance RMSE=1.2202
# obsm=1.20, Mean RMSE=1.5407, Variance RMSE=1.8651,  Without spinup: Mean RMSE=1.4873, Variance RMSE=1.7745
# obsm=1.45, Mean RMSE=1.9076, Variance RMSE=1.6402,  Without spinup: Mean RMSE=1.8446, Variance RMSE=1.5110
# obsm=1.70, Mean RMSE=2.3568, Variance RMSE=3.2031,  Without spinup: Mean RMSE=2.2806, Variance RMSE=3.0769
# obsm=1.95, Mean RMSE=2.6777, Variance RMSE=4.7879,  Without spinup: Mean RMSE=2.5648, Variance RMSE=4.4463
# obsm=2.20, Mean RMSE=2.6764, Variance RMSE=4.0206,  Without spinup: Mean RMSE=2.5884, Variance RMSE=3.8297
# obsm=2.45, Mean RMSE=2.9069, Variance RMSE=4.3095,  Without spinup: Mean RMSE=2.8283, Variance RMSE=4.2102
# obsm=2.70, Mean RMSE=3.3026, Variance RMSE=5.1313,  Without spinup: Mean RMSE=3.2262, Variance RMSE=5.0658
# obsm=2.95, Mean RMSE=3.4585, Variance RMSE=5.9639,  Without spinup: Mean RMSE=3.4070, Variance RMSE=6.0120
# obsm=3.20, Mean RMSE=3.8501, Variance RMSE=6.9784,  Without spinup: Mean RMSE=3.7671, Variance RMSE=6.9003
# obsm=3.45, Mean RMSE=3.9213, Variance RMSE=6.7794,  Without spinup: Mean RMSE=3.8368, Variance RMSE=6.6838
# obsm=3.70, Mean RMSE=4.4027, Variance RMSE=7.4229,  Without spinup: Mean RMSE=4.3098, Variance RMSE=7.2715
# obsm=3.95, Mean RMSE=4.3147, Variance RMSE=7.5160,  Without spinup: Mean RMSE=4.2224, Variance RMSE=7.3870
# obsm=4.20, Mean RMSE=4.6207, Variance RMSE=8.2660,  Without spinup: Mean RMSE=4.5436, Variance RMSE=8.2719
# obsm=4.45, Mean RMSE=4.9230, Variance RMSE=8.6528,  Without spinup: Mean RMSE=4.8420, Variance RMSE=8.6049
# obsm=4.70, Mean RMSE=5.2828, Variance RMSE=9.4363,  Without spinup: Mean RMSE=5.1961, Variance RMSE=9.4217
# obsm=4.95, Mean RMSE=5.4217, Variance RMSE=10.0550,  Without spinup: Mean RMSE=5.3369, Variance RMSE=10.0653
# obsm=5.20, Mean RMSE=5.6890, Variance RMSE=9.8114,  Without spinup: Mean RMSE=5.6178, Variance RMSE=9.8745

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_mean = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_mean, mean_rmse, label='with spinup period')
axs[0].plot(ex_mean, mean_rmse_nospn, label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')
axs[0].hlines(y=np.sqrt(2), xmin=0, xmax=5.4, ls='dashed', alpha=0.4)
axs[0].text(3.5, np.sqrt(2)+0.1, 'Obs var=sqrt(2)', fontsize=13)

axs[1].plot(ex_mean, var_rmse, label='with spinup period')
axs[1].plot(ex_mean, var_rmse_nospn, label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %% [markdown]
# # Third moment

# %% [markdown]
# ### Assimilate skew observation based on normality test

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_015_135.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.15', '0.45', '0.75', '1.05', '1.35'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_a in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_a]
    
    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'alpha={ex_a}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_a)
    
# CNTL
plt.plot(ts, rmse_hy, color='k', label='CNTL')
    
# no DA
forecast = lorenz63_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
plt.legend()
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# alpha=0.15, Mean RMSE=0.7289, Variance RMSE=0.3061,  Without spinup: Mean RMSE=0.6794, Variance RMSE=0.1904
# alpha=0.45, Mean RMSE=0.7636, Variance RMSE=0.3774,  Without spinup: Mean RMSE=0.7337, Variance RMSE=0.2627
# alpha=0.75, Mean RMSE=1.0152, Variance RMSE=1.0217,  Without spinup: Mean RMSE=0.9797, Variance RMSE=0.9428
# alpha=1.05, Mean RMSE=0.8584, Variance RMSE=0.4194,  Without spinup: Mean RMSE=0.7996, Variance RMSE=0.2673
# alpha=1.35, Mean RMSE=0.9099, Variance RMSE=0.5711,  Without spinup: Mean RMSE=0.8662, Variance RMSE=0.4615

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_alpha = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_alpha, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_alpha, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(ex_alpha)
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_alpha, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_alpha, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(ex_alpha)
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Assimilate more extreme skewness

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_130_330.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['1.30', '1.55', '1.80', '2.05', '2.30', '2.55', '2.80', '3.05', '3.30'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_a in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_a]
    
    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'alpha={ex_a}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_a)
    
# CNTL
plt.plot(ts, rmse_hy, color='k', label='CNTL')
    
# no DA
forecast = lorenz63_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# alpha=1.30, Mean RMSE=0.8912, Variance RMSE=0.5405,  Without spinup: Mean RMSE=0.8435, Variance RMSE=0.4051
# alpha=1.55, Mean RMSE=0.8500, Variance RMSE=0.4748,  Without spinup: Mean RMSE=0.7962, Variance RMSE=0.3159
# alpha=1.80, Mean RMSE=0.8131, Variance RMSE=0.4008,  Without spinup: Mean RMSE=0.7727, Variance RMSE=0.2909
# alpha=2.05, Mean RMSE=0.7303, Variance RMSE=0.2781,  Without spinup: Mean RMSE=0.6847, Variance RMSE=0.1308
# alpha=2.30, Mean RMSE=0.8925, Variance RMSE=0.5707,  Without spinup: Mean RMSE=0.8248, Variance RMSE=0.3705
# alpha=2.55, Mean RMSE=0.9014, Variance RMSE=0.5501,  Without spinup: Mean RMSE=0.8691, Variance RMSE=0.4647
# alpha=2.80, Mean RMSE=0.8210, Variance RMSE=0.3661,  Without spinup: Mean RMSE=0.7951, Variance RMSE=0.2632
# alpha=3.05, Mean RMSE=0.8366, Variance RMSE=0.3491,  Without spinup: Mean RMSE=0.7927, Variance RMSE=0.2122
# alpha=3.30, Mean RMSE=0.9190, Variance RMSE=0.5129,  Without spinup: Mean RMSE=0.8905, Variance RMSE=0.4195

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_alpha = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_alpha, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_alpha, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(ex_alpha)
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_alpha, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_alpha, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(ex_alpha)
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Check the ratio of skew observation located bwteen -2*std ~ 2*std

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_130_330.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['1.30', '1.55', '1.80', '2.05', '2.30', '2.55', '2.80', '3.05', '3.30'])

# %%
nrows = len(ex_obs_dict.keys())
fig, axs = plt.subplots(nrows=nrows, figsize=(5, 20), sharex=True)

for i, (key, obs) in enumerate(ex_obs_dict.items()):
    obserr = (obs - X_nature[:,::8]).ravel()
    axs[i].hist(obserr)
    
    std = np.sqrt(2)
    axs[i].vlines([2*std, -2*std], ymin=0, ymax=200, ls='dashed')
    axs[i].set_xlim([-4, 6])
    axs[i].set_title(f'alpha = {key}')
    
    total_size = obserr.size
    within_size = obserr[np.where((obserr <= 2*std) & (obserr >= -2*std))].size
    ratio = within_size / total_size
    axs[i].text(-1, 175, f'ratio={ratio:.2f}', fontsize=13)

plt.tight_layout()

# %% [markdown]
# # Fourth moment

# %% [markdown]
# ### Assimilate kurtosis observation based on normality test

# %%
ex_obs_dict = pickle.load(open('./data/obs_kurtosis_050_220.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.5', '0.6', '0.7', '0.8', '0.9', '1.2', '1.6', '1.8', '2.0', '2.2'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_d in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_d]
    
    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'delta={ex_d}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_d)
    
# CNTL
plt.plot(ts, rmse_hy, color='k', label='CNTL')
    
# no DA
forecast = lorenz63_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# delta=0.5, Mean RMSE=0.7269, Variance RMSE=0.3210,  Without spinup: Mean RMSE=0.6849, Variance RMSE=0.2065
# delta=0.6, Mean RMSE=0.9132, Variance RMSE=0.8018,  Without spinup: Mean RMSE=0.8514, Variance RMSE=0.6282
# delta=0.7, Mean RMSE=0.9424, Variance RMSE=0.5520,  Without spinup: Mean RMSE=0.8788, Variance RMSE=0.3773
# delta=0.8, Mean RMSE=0.8299, Variance RMSE=0.3408,  Without spinup: Mean RMSE=0.8025, Variance RMSE=0.2432
# delta=0.9, Mean RMSE=0.6879, Variance RMSE=0.3003,  Without spinup: Mean RMSE=0.6318, Variance RMSE=0.1233
# delta=1.2, Mean RMSE=0.8042, Variance RMSE=0.3515,  Without spinup: Mean RMSE=0.7522, Variance RMSE=0.1925
# delta=1.6, Mean RMSE=0.7841, Variance RMSE=0.3169,  Without spinup: Mean RMSE=0.7412, Variance RMSE=0.1864
# delta=1.8, Mean RMSE=0.8749, Variance RMSE=0.5522,  Without spinup: Mean RMSE=0.8189, Variance RMSE=0.4305
# delta=2.0, Mean RMSE=1.0088, Variance RMSE=0.8713,  Without spinup: Mean RMSE=0.9470, Variance RMSE=0.7339
# delta=2.2, Mean RMSE=0.8932, Variance RMSE=0.4401,  Without spinup: Mean RMSE=0.8389, Variance RMSE=0.2863

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_delta = list(map(lambda s: float(s), ex_obs_dict.keys()))
xticks = np.arange(min(ex_delta), max(ex_delta), 0.2)

axs[0].plot(ex_delta, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_delta, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(xticks)
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_delta, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_delta, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(xticks)
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %%
import seaborn as sns

fig, ax = plt.subplots()

for key in ex_obs_dict.keys():
    obs = ex_obs_dict[key]
    obserr = obs - X_nature[:,::8]
    obserr = obserr.ravel()
    sns.kdeplot(obserr, label=key, ax=ax)
plt.xlim([-20, 20])
# Out:
# (-20, 20)

# %% [markdown]
# ### Assimilate kurtosis observation with more extreme delta

# %%
ex_obs_dict = pickle.load(open('./data/obs_kurtosis_010_340.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.1', '0.2', '0.3', '0.4', '2.5', '2.8', '3.1', '3.4'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_d in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_d]
    
    hy = Hybrid3DEnVar(lorenz63_fdm, dt)
    hy.list_params()
    params = {
        'X_ini': X_ini,
        'X_ens_ini': X_ens_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(3),
        'alpha': 0.3,
        'inflat': 1.4,
        'beta': 0.7
    }
    hy.set_params(**params)
    hy.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(hy.analysis_3dvar, X_nature)
    print(
        f'delta={ex_d}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_d)
    
# CNTL
plt.plot(ts, rmse_hy, color='k', label='CNTL')
    
# no DA
forecast = lorenz63_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# delta=0.1, Mean RMSE=0.3272, Variance RMSE=0.2760,  Without spinup: Mean RMSE=0.2612, Variance RMSE=0.0855
# delta=0.2, Mean RMSE=0.7388, Variance RMSE=1.2295,  Without spinup: Mean RMSE=0.6846, Variance RMSE=1.1169
# delta=0.3, Mean RMSE=0.7909, Variance RMSE=0.6994,  Without spinup: Mean RMSE=0.7169, Variance RMSE=0.4951
# delta=0.4, Mean RMSE=0.7072, Variance RMSE=0.4510,  Without spinup: Mean RMSE=0.6442, Variance RMSE=0.2903
# delta=2.5, Mean RMSE=0.9248, Variance RMSE=0.5303,  Without spinup: Mean RMSE=0.8898, Variance RMSE=0.4252
# delta=2.8, Mean RMSE=0.8062, Variance RMSE=0.4469,  Without spinup: Mean RMSE=0.7730, Variance RMSE=0.3331
# delta=3.1, Mean RMSE=0.8691, Variance RMSE=0.5268,  Without spinup: Mean RMSE=0.8401, Variance RMSE=0.4194
# delta=3.4, Mean RMSE=0.8670, Variance RMSE=0.3314,  Without spinup: Mean RMSE=0.8218, Variance RMSE=0.2208

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_delta = list(map(lambda s: float(s), ex_obs_dict.keys()))
xticks = np.arange(min(ex_delta), max(ex_delta), 0.2)

axs[0].plot(ex_delta[:4], mean_rmse[:4], 'b.-', alpha=0.6, label='with spinup period')
axs[0].plot(ex_delta[4:], mean_rmse[4:], 'b.-', alpha=0.6)
axs[0].plot(ex_delta[:4], mean_rmse_nospn[:4], 'g.-', alpha=0.6, label='without spinup period')
axs[0].plot(ex_delta[4:], mean_rmse_nospn[4:], 'g.-', alpha=0.6)
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(xticks)
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_delta[:4], var_rmse[:4], 'b.-', alpha=0.6, label='with spinup period')
axs[1].plot(ex_delta[4:], var_rmse[4:], 'b.-', alpha=0.6)
axs[1].plot(ex_delta[:4], var_rmse_nospn[:4], 'g.-', alpha=0.6, label='without spinup period')
axs[1].plot(ex_delta[4:], var_rmse_nospn[4:], 'g.-', alpha=0.6)
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(xticks)
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %%
fig, ax = plt.subplots()

for key in ex_obs_dict.keys():
    obs = ex_obs_dict[key]
    obserr = obs - X_nature[:,::8]
    obserr = obserr.ravel()
    sns.kdeplot(obserr, label=key, ax=ax)
plt.xlim([-20, 20]);
