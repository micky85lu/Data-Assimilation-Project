# %%
# %matplotlib inline
import pickle
import numpy as np
import matplotlib.pyplot as plt

from model import lorenz63_fdm
from assimilation import OI, ExtendedKF, EnKF, M3DVar

# %%
X_nature = np.load('./data/X_nature.npy')
X_ini = np.load('./data/X_ini.npy')
ts = np.load('./data/time_span.npy')
Pb = np.load('./data/Pb.npy')
R = np.load('./data/R.npy')

# %%
dt = 0.01
obs_intv = 8

# %%
# generate initial ensemble
N_ens = 30
rng = np.random.RandomState(42)
X_ens_ini = rng.multivariate_normal(X_ini.ravel(), Pb, size=N_ens).T  # (3, N_ens)

# %%
def RMSE(forecast, nature):
    return np.sqrt(np.mean((forecast-nature)**2, axis=0))

# %% [markdown]
# # Assimilate normal observations

# %%
# normal observation
X_obs = np.load('./data/obs_normal.npy')

tdv = M3DVar(lorenz63_fdm, dt)
tdv.list_params()
params = {
    'X_ini': X_ini,
    'obs': X_obs,
    'obs_interv': 8,
    'Pb': Pb,
    'R': R,
    'H_func': lambda arr: arr,
}
tdv.set_params(**params)
tdv.cycle()

rmse_tdv = RMSE(tdv.analysis, X_nature)

plt.figure(figsize=(10, 5))
plt.plot(ts, rmse_tdv)
plt.xlabel('Time')
plt.ylabel('RMSE')
plt.ylim([-0.2, 10])
print(rmse_tdv.mean())
# Out:
# 0.9437467280394009

# %% [markdown]
# # Gamma distribution

# %%
from scipy.stats import gamma

plt.figure(figsize=(10, 5))

x = np.arange(-5, 5, 0.05)
alphas = [0.5, 1, 1.5, 2.5, 100]
for alpha in alphas:
    beta = np.sqrt(2/alpha)
    loc = -np.sqrt(2*alpha)
    pdf = gamma.pdf(x, alpha, loc=loc, scale=beta)
    plt.plot(x, pdf, label=f'{alpha}')
plt.legend()

# %% [markdown]
# ### Generate observations

# %%
ex_obs_dict = {}

alphas = [0.5, 1, 1.5, 2.5, 100]
for alpha in alphas:
    beta = np.sqrt(2/alpha)
    loc = -np.sqrt(2*alpha)
    samples = gamma.rvs(alpha, loc=loc, scale=beta, size=X_nature.shape)
    
    samples_c = samples.copy()
    samples_c[:,::obs_intv] = 0
    samples = samples - samples_c
    X_obserr = samples
        
    X_obs = X_nature + X_obserr
    X_obs = X_obs[:,::obs_intv]
    
    key = f'{alpha:.1f}'
    ex_obs_dict[key] = X_obs
    
ex_obs_dict.keys()
# Out:
# dict_keys(['0.5', '1.0', '1.5', '2.5', '100.0'])

# %% [markdown]
# ### Assimilate gamma observations

# %%
plt.figure(figsize=(10, 5))

for key, obs in ex_obs_dict.items():
    tdv = M3DVar(lorenz63_fdm, dt)
    tdv.list_params()
    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
    }
    tdv.set_params(**params)
    tdv.cycle()

    rmse_tdv = RMSE(tdv.analysis, X_nature)

    plt.plot(ts, rmse_tdv, label=key)
    print(key, rmse_tdv.mean(), rmse_tdv.var())

plt.legend();
# Out:
# 0.5 0.943628307562 0.4347936936224622
# 1.0 0.9317298515559677 0.4379642720398348
# 1.5 0.9559612294059163 0.4280040500356643
# 2.5 0.9451116011709896 0.3907810258632789
# 100.0 0.9424451157939899 0.37356182379280645

# %% [markdown]
# # Cauchy

# %%
from scipy.stats import cauchy, norm

x = np.arange(-4, 4, 0.05)
plt.plot(x, cauchy.pdf(x, scale=np.sqrt(2)), label='cauchy')
plt.legend();

# %%
x = np.arange(-4, 4, 0.05)
plt.plot(x, cauchy.pdf(x, scale=np.sqrt(2)), label='cauchy')
plt.plot(x, norm.pdf(x, scale=np.sqrt(2)), label='gaussian')
plt.legend();

# %% [markdown]
# ### Generate chauchy observation

# %%
samples = cauchy.rvs(scale=np.sqrt(2), size=X_nature.shape)
   
samples_c = samples.copy()
samples_c[:,::obs_intv] = 0
samples = samples - samples_c
X_obserr = samples
        
X_obs = X_nature + X_obserr
X_obs = X_obs[:,::obs_intv]

# %%
plt.figure(figsize=(10, 5))

tdv = M3DVar(lorenz63_fdm, dt)
params = {
    'X_ini': X_ini,
    'obs': X_obs,
    'obs_interv': 8,
    'Pb': Pb,
    'R': R,
    'H_func': lambda arr: arr,
}
tdv.set_params(**params)
tdv.cycle()

rmse_tdv = RMSE(tdv.analysis, X_nature)

plt.plot(ts, rmse_tdv)
plt.xlabel('Time')
plt.ylabel('RMSE')
print(rmse_tdv.mean(), rmse_tdv.var())
# Out:
# C:\Users\dog\Desktop\jupyter_work\SideProject2\DA_project\Untitled Folder\model.py:25: RuntimeWarning: overflow encountered in double_scalars
#   y[i] = y[i-1] + (r*x[i-1] - y[i-1] - x[i-1]*z[i-1]) * dt
# C:\Users\dog\Desktop\jupyter_work\SideProject2\DA_project\Untitled Folder\model.py:26: RuntimeWarning: overflow encountered in double_scalars
#   z[i] = z[i-1] + (x[i-1]*y[i-1] - b*z[i-1]) * dt
# C:\Users\dog\Desktop\jupyter_work\SideProject2\DA_project\Untitled Folder\model.py:25: RuntimeWarning: invalid value encountered in double_scalars
#   y[i] = y[i-1] + (r*x[i-1] - y[i-1] - x[i-1]*z[i-1]) * dt
# C:\Users\dog\Desktop\jupyter_work\SideProject2\DA_project\Untitled Folder\model.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   z[i] = z[i-1] + (x[i-1]*y[i-1] - b*z[i-1]) * dt
# C:\Users\dog\Anaconda3\envs\work\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in square
# nan nan

# %%
plt.figure(figsize=(10, 5))
plt.plot(ts, rmse_tdv)
plt.xlabel('Time')
plt.ylabel('RMSE')
plt.ylim([0, 10]);

# %%
plt.figure(figsize=(10, 5))
plt.plot(ts, X_nature[0,:], label='nature')
plt.plot(ts, tdv.analysis[0,:], label='analysis')
plt.xlabel('Time')
plt.ylabel('RMSE')
plt.legend()
plt.ylim([-20, 20]);

# %%
print(X_obserr.max(), X_obserr.min())
# Out:
# 666.9178002767901 -1458.7080622619872

# %%
std = np.sqrt(2)
obserr_no0 = X_obserr[:,::obs_intv].ravel()
total_size = obserr_no0.size
within_size = np.sum((obserr_no0 >= -2*std) & (obserr_no0 <= 2*std))

plt.bar(0, total_size, facecolor='white', edgecolor='k')
plt.bar(0, within_size, edgecolor='k')
plt.xlim([-2, 2])
plt.xticks([0], [])
plt.text(-1.5, 300, f'ratio={within_size/total_size:.2f}', fontsize=15);

# %%
plt.boxplot(X_obserr.ravel());

# %%
plt.boxplot(X_obserr.ravel())
plt.ylim([-100, 100])
# Out:
# (-100, 100)

# %% [markdown]
# ### QC for cauchy

# %% [markdown]
# #### Just simply replace the original observation by truth value if the observation value is greater than |N$\sqrt{2}$|, N=2,3,4,5.

# %%
plt.figure(figsize=(10, 5))

obsqc = {}
for N in range(2, 6):
    std = np.sqrt(2)
    X_obserr_qc = X_obserr.copy()
    X_obserr_qc[np.abs(X_obserr) >= N*std] = 0

    X_obs_qc = X_nature + X_obserr_qc
    X_obs_qc = X_obs_qc[:,::obs_intv]
    obsqc[N] = X_obs_qc

    tdv = M3DVar(lorenz63_fdm, dt)
    tdv.list_params()
    params = {
        'X_ini': X_ini,
        'obs': X_obs_qc,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
    }
    tdv.set_params(**params)
    tdv.cycle()

    rmse_tdv = RMSE(tdv.analysis, X_nature)
    plt.plot(ts, rmse_tdv, label=str(N))
    print(f'N={N}, RMSE mean={rmse_tdv.mean():.4f}, RMSE variance={rmse_tdv.var():.4f}')
    
plt.legend()
plt.xlabel('Time')
plt.ylabel('RMSE');
# Out:
# N=2, RMSE mean=0.8306, RMSE variance=0.3655
# N=3, RMSE mean=0.9362, RMSE variance=0.4070
# N=4, RMSE mean=1.0491, RMSE variance=0.4419
# N=5, RMSE mean=1.1911, RMSE variance=0.5900

# %%
std = np.sqrt(2)
for N, obsq in obsqc.items():
    obsq_err = obsq - X_nature[:,::obs_intv]
    
    total_size = obsq_err.size
    within_size = np.sum((obsq_err >= -2*std) & (obsq_err <= 2*std))
    
    plt.bar(N, total_size, facecolor='white', edgecolor='k')
    plt.bar(N, within_size, edgecolor='k')
    plt.text(N-0.08, 300, f'{within_size/total_size:.2f}')

plt.xticks([i for i in range(2, 6)])
plt.xlabel('N');
