# %%
# %matplotlib inline
import pickle
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')

from model import lorenz96_fdm
from model import M96 as M
from assimilation import OI, ExtendedKF, EnKF, M3DVar

# %%
X_nature = np.load('./data/X_nature.npy')
X_ini = np.load('./data/X_ini.npy')
ts = np.load('./data/time_span.npy')
Pb = np.load('./data/Pb_assum.npy')
R = np.load('./data/R.npy')

# %%
dt = 0.01
ndim = 40
F = 8

# %%
def RMSE(forecast, nature):
    return np.sqrt(np.mean((forecast-nature)**2, axis=0))

# %% [markdown]
# # Assimilate normal observation

# %% [markdown]
# #### `rmse_ekf` as CNTL in the later experiments

# %%
# normal observation
X_obs = np.load('./data/obs_normal.npy')

# %%
ekf = ExtendedKF(lorenz96_fdm, dt)
ekf.list_params()
params = {
    'X_ini': X_ini,
    'obs': X_obs,
    'obs_interv': 8,
    'Pb': Pb,
    'R': R,
    'H_func': lambda arr: arr,
    'H': np.eye(ndim),
    'M': lambda X: M(X.ravel(), dt, F),
    'alpha': 0.3,
    'inflat': 1.4
}
ekf.set_params(**params)
ekf.cycle()

# %%
rmse_ekf = RMSE(ekf.analysis, X_nature)

plt.figure(figsize=(10, 5))
plt.plot(ts, rmse_ekf)
plt.xlabel('Time')
plt.ylabel('RMSE')
plt.ylim([-0.2, 6])
plt.title('EKF analysis RMSE')
print(rmse_ekf.mean())
# Out:
# 0.8943346827943697

# %% [markdown]
# # First moment

# %% [markdown]
# ### Assimilate bias observations based on normality test

# %%
# first moment
ex_obs_dict = pickle.load(open('./data/obs_bias_005_040.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.05', '0.15', '0.20', '0.25', '0.30', '0.35', '0.40'])

# %%
plt.figure(figsize=(12, 6))

mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

for obsm in ex_obs_dict.keys():
    obs = ex_obs_dict[obsm]

    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'obsm={obsm}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=obsm)
    
# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
plt.plot(ts, rmse_ekf, 'k', label='CNTL')
plt.legend()
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# obsm=0.05, Mean RMSE=0.8696, Variance RMSE=0.0349,  Without spinup: Mean RMSE=0.8569, Variance RMSE=0.0249
# obsm=0.15, Mean RMSE=0.8876, Variance RMSE=0.0261,  Without spinup: Mean RMSE=0.8774, Variance RMSE=0.0161
# obsm=0.20, Mean RMSE=0.8678, Variance RMSE=0.0241,  Without spinup: Mean RMSE=0.8571, Variance RMSE=0.0185
# obsm=0.25, Mean RMSE=0.8877, Variance RMSE=0.0225,  Without spinup: Mean RMSE=0.8790, Variance RMSE=0.0177
# obsm=0.30, Mean RMSE=0.9103, Variance RMSE=0.0239,  Without spinup: Mean RMSE=0.9021, Variance RMSE=0.0181
# obsm=0.35, Mean RMSE=0.9117, Variance RMSE=0.0263,  Without spinup: Mean RMSE=0.9008, Variance RMSE=0.0179
# obsm=0.40, Mean RMSE=0.9209, Variance RMSE=0.0294,  Without spinup: Mean RMSE=0.9129, Variance RMSE=0.0231

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_mean = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_mean, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_mean, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_mean, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_mean, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Assimilate more extreme bias observations

# %%
ex_obs_dict = pickle.load(open('./data/obs_bias_020_520.pickle', 'rb'))

# %%
import matplotlib.cm as cm


mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))
colors = cm.GnBu(np.linspace(0, 1, len(ex_obs_dict.keys())))

for obsm, color in zip(ex_obs_dict.keys(), colors):
    obs = ex_obs_dict[obsm]

    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'obsm={obsm}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())
    
    plt.plot(ts, rmse, color=color, label=obsm)
    
# CNTL
plt.plot(ts, rmse_ekf, color='k', label='CNTL')

# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)

ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('RMSE');
# Out:
# obsm=0.20, Mean RMSE=0.8900, Variance RMSE=0.0264,  Without spinup: Mean RMSE=0.8803, Variance RMSE=0.0186
# obsm=0.45, Mean RMSE=0.9387, Variance RMSE=0.0275,  Without spinup: Mean RMSE=0.9299, Variance RMSE=0.0225
# obsm=0.70, Mean RMSE=1.0335, Variance RMSE=0.0299,  Without spinup: Mean RMSE=1.0309, Variance RMSE=0.0278
# obsm=0.95, Mean RMSE=1.1740, Variance RMSE=0.0272,  Without spinup: Mean RMSE=1.1732, Variance RMSE=0.0249
# obsm=1.20, Mean RMSE=1.3365, Variance RMSE=0.0358,  Without spinup: Mean RMSE=1.3412, Variance RMSE=0.0346
# obsm=1.45, Mean RMSE=1.5563, Variance RMSE=0.0288,  Without spinup: Mean RMSE=1.5614, Variance RMSE=0.0270
# obsm=1.70, Mean RMSE=1.7429, Variance RMSE=0.0405,  Without spinup: Mean RMSE=1.7456, Variance RMSE=0.0397
# obsm=1.95, Mean RMSE=1.9281, Variance RMSE=0.0443,  Without spinup: Mean RMSE=1.9341, Variance RMSE=0.0431
# obsm=2.20, Mean RMSE=2.1701, Variance RMSE=0.0437,  Without spinup: Mean RMSE=2.1785, Variance RMSE=0.0412
# obsm=2.45, Mean RMSE=2.4129, Variance RMSE=0.0433,  Without spinup: Mean RMSE=2.4207, Variance RMSE=0.0420
# obsm=2.70, Mean RMSE=2.6052, Variance RMSE=0.0570,  Without spinup: Mean RMSE=2.6192, Variance RMSE=0.0517
# obsm=2.95, Mean RMSE=2.8370, Variance RMSE=0.0602,  Without spinup: Mean RMSE=2.8519, Variance RMSE=0.0532
# obsm=3.20, Mean RMSE=3.0498, Variance RMSE=0.0751,  Without spinup: Mean RMSE=3.0678, Variance RMSE=0.0643
# obsm=3.45, Mean RMSE=3.2837, Variance RMSE=0.0745,  Without spinup: Mean RMSE=3.3054, Variance RMSE=0.0568
# obsm=3.70, Mean RMSE=3.4645, Variance RMSE=0.0866,  Without spinup: Mean RMSE=3.4859, Variance RMSE=0.0702
# obsm=3.95, Mean RMSE=3.7321, Variance RMSE=0.0992,  Without spinup: Mean RMSE=3.7599, Variance RMSE=0.0691
# obsm=4.20, Mean RMSE=3.9924, Variance RMSE=0.1182,  Without spinup: Mean RMSE=4.0169, Variance RMSE=0.0912
# obsm=4.45, Mean RMSE=4.1970, Variance RMSE=0.1272,  Without spinup: Mean RMSE=4.2288, Variance RMSE=0.0906
# obsm=4.70, Mean RMSE=4.3803, Variance RMSE=0.1329,  Without spinup: Mean RMSE=4.4142, Variance RMSE=0.0863
# obsm=4.95, Mean RMSE=4.6392, Variance RMSE=0.1504,  Without spinup: Mean RMSE=4.6733, Variance RMSE=0.1056
# obsm=5.20, Mean RMSE=4.8759, Variance RMSE=0.1498,  Without spinup: Mean RMSE=4.9122, Variance RMSE=0.0913

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_mean = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_mean, mean_rmse, label='with spinup period')
axs[0].plot(ex_mean, mean_rmse_nospn, label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xlabel('Obs error mean')
axs[0].set_ylabel('RMSE')
axs[0].hlines(y=np.sqrt(2), xmin=0, xmax=5.4, ls='dashed', alpha=0.4)
axs[0].text(3.5, np.sqrt(2)+0.1, 'Obs var=sqrt(2)', fontsize=13)

axs[1].plot(ex_mean, var_rmse, label='with spinup period')
axs[1].plot(ex_mean, var_rmse_nospn, label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xlabel('Obs error mean')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# # Third moment

# %% [markdown]
# ### Assimilate skew observation based on normality test

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_015_135.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.15', '0.45', '0.75', '1.05', '1.35'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_a in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_a]
    
    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'alpha={ex_a}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_a)
    
# CNTL
plt.plot(ts, rmse_ekf, color='k', label='CNTL')
    
# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
plt.legend()
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# alpha=0.15, Mean RMSE=0.8966, Variance RMSE=0.0252,  Without spinup: Mean RMSE=0.8910, Variance RMSE=0.0186
# alpha=0.45, Mean RMSE=0.8910, Variance RMSE=0.0263,  Without spinup: Mean RMSE=0.8802, Variance RMSE=0.0159
# alpha=0.75, Mean RMSE=0.8756, Variance RMSE=0.0225,  Without spinup: Mean RMSE=0.8649, Variance RMSE=0.0128
# alpha=1.05, Mean RMSE=0.8728, Variance RMSE=0.0194,  Without spinup: Mean RMSE=0.8624, Variance RMSE=0.0128
# alpha=1.35, Mean RMSE=0.8814, Variance RMSE=0.0228,  Without spinup: Mean RMSE=0.8732, Variance RMSE=0.0157

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_alpha = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_alpha, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_alpha, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(ex_alpha)
axs[0].set_xlabel('alpha')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_alpha, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_alpha, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(ex_alpha)
axs[1].set_xlabel('alpha')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Assimilate more extreme skewness

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_130_330.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['1.30', '1.55', '1.80', '2.05', '2.30', '2.55', '2.80', '3.05', '3.30'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_a in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_a]
    
    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'alpha={ex_a}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_a)
    
# CNTL
plt.plot(ts, rmse_ekf, color='k', label='CNTL')
    
# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# alpha=1.30, Mean RMSE=0.8711, Variance RMSE=0.0236,  Without spinup: Mean RMSE=0.8592, Variance RMSE=0.0130
# alpha=1.55, Mean RMSE=0.8702, Variance RMSE=0.0212,  Without spinup: Mean RMSE=0.8600, Variance RMSE=0.0135
# alpha=1.80, Mean RMSE=0.8758, Variance RMSE=0.0215,  Without spinup: Mean RMSE=0.8675, Variance RMSE=0.0130
# alpha=2.05, Mean RMSE=0.8783, Variance RMSE=0.0208,  Without spinup: Mean RMSE=0.8698, Variance RMSE=0.0148
# alpha=2.30, Mean RMSE=0.8658, Variance RMSE=0.0185,  Without spinup: Mean RMSE=0.8587, Variance RMSE=0.0119
# alpha=2.55, Mean RMSE=0.8862, Variance RMSE=0.0231,  Without spinup: Mean RMSE=0.8789, Variance RMSE=0.0160
# alpha=2.80, Mean RMSE=0.8663, Variance RMSE=0.0200,  Without spinup: Mean RMSE=0.8572, Variance RMSE=0.0140
# alpha=3.05, Mean RMSE=0.8972, Variance RMSE=0.0282,  Without spinup: Mean RMSE=0.8857, Variance RMSE=0.0159
# alpha=3.30, Mean RMSE=0.8860, Variance RMSE=0.0334,  Without spinup: Mean RMSE=0.8704, Variance RMSE=0.0182

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_alpha = list(map(lambda s: float(s), ex_obs_dict.keys()))
axs[0].plot(ex_alpha, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_alpha, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(ex_alpha)
axs[0].set_xlabel('alpha')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_alpha, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_alpha, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(ex_alpha)
axs[1].set_xlabel('alpha')
axs[1].set_ylabel('RMSE');

# %% [markdown]
# ### Repeated assimilate skew observation based on normality test (repeat 10 times)

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_015_135.pickle', 'rb'))
ex_alpha = ex_obs_dict.keys()
ex_alpha = list(map(float, ex_alpha))
ex_alpha
# Out:
# [0.15, 0.45, 0.75, 1.05, 1.35]

# %%
from gen_skew_func import gen_skew_obs

rmse_dict = {}
for ex_a in ex_alpha:
    print(ex_a)
    rmse = np.zeros_like(ts)
    
    for _ in range(10):
        obs = gen_skew_obs(mean=0, var=2, alpha=ex_a, obs_intv=8)
        
        params = {
            'X_ini': X_ini,
            'obs': obs,
            'obs_interv': 8,
            'Pb': Pb,
            'R': R,
            'H_func': lambda arr: arr,
            'H': np.eye(ndim),
            'M': lambda X: M(X.ravel(), dt, F),
            'alpha': 0.3,
            'inflat': 1.4
        }
        ekf = ExtendedKF(lorenz96_fdm, dt)
        ekf.set_params(**params)
        ekf.cycle()
        rmse += RMSE(ekf.analysis, X_nature)

    rmse /= 10
    key = f'{ex_a:.2f}'
    rmse_dict[key] = rmse
# Out:
# 0.15
# 0.45
# 0.75
# 1.05
# 1.35

# %%
plt.figure(figsize=(12, 6))
plt.plot(ts, rmse_ekf, 'k', label='CNTL')

for key, rmse in rmse_dict.items():
    print(f'alpha = {key}, mean RMSE = {rmse.mean():.4f}')
    plt.plot(ts, rmse, label=key)

plt.legend()
plt.title('Mean RMSE')
plt.xlabel('Time')
plt.ylabel('RMSE');
# Out:
# alpha = 0.15, mean RMSE = 0.8781
# alpha = 0.45, mean RMSE = 0.8766
# alpha = 0.75, mean RMSE = 0.8794
# alpha = 1.05, mean RMSE = 0.8814
# alpha = 1.35, mean RMSE = 0.8792

# %% [markdown]
# ### Repeated assimilate skew observations for more extreme alpha (repeat 10 times)

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_130_330.pickle', 'rb'))
ex_alpha = ex_obs_dict.keys()
ex_alpha = list(map(float, ex_alpha))
ex_alpha
# Out:
# [1.3, 1.55, 1.8, 2.05, 2.3, 2.55, 2.8, 3.05, 3.3]

# %%
from gen_skew_func import gen_skew_obs

rmse_dict = {}
for ex_a in ex_alpha:
    print(ex_a)
    rmse = np.zeros_like(ts)
    
    for _ in range(10):
        obs = gen_skew_obs(mean=0, var=2, alpha=ex_a, obs_intv=8)
        
        params = {
            'X_ini': X_ini,
            'obs': obs,
            'obs_interv': 8,
            'Pb': Pb,
            'R': R,
            'H_func': lambda arr: arr,
            'H': np.eye(ndim),
            'M': lambda X: M(X.ravel(), dt, F),
            'alpha': 0.3,
            'inflat': 1.4
        }
        ekf = ExtendedKF(lorenz96_fdm, dt)
        ekf.set_params(**params)
        ekf.cycle()
        rmse += RMSE(ekf.analysis, X_nature)

    rmse /= 10
    key = f'{ex_a:.2f}'
    rmse_dict[key] = rmse
# Out:
# 1.3
# 1.55
# 1.8
# 2.05
# 2.3
# 2.55
# 2.8
# 3.05
# 3.3

# %%
plt.figure(figsize=(12, 6))
plt.plot(ts, rmse_ekf, 'k', label='CNTL')

for key, rmse in rmse_dict.items():
    print(f'alpha = {key}, mean RMSE = {rmse.mean():.4f}')
    plt.plot(ts, rmse, label=key)

plt.legend()
plt.title('Mean RMSE')
plt.xlabel('Time')
plt.ylabel('RMSE');
# Out:
# alpha = 1.30, mean RMSE = 0.8782
# alpha = 1.55, mean RMSE = 0.8900
# alpha = 1.80, mean RMSE = 0.8783
# alpha = 2.05, mean RMSE = 0.8859
# alpha = 2.30, mean RMSE = 0.8906
# alpha = 2.55, mean RMSE = 0.8747
# alpha = 2.80, mean RMSE = 0.8775
# alpha = 3.05, mean RMSE = 0.8742
# alpha = 3.30, mean RMSE = 0.8862

# %%
mean_rmse = []
for key, rmse in rmse_dict.items():
    mean_rmse.append(rmse.mean())


plt.plot(ex_alpha, mean_rmse, '.-')
plt.title('RMSE Mean')
plt.xticks(ex_alpha)
plt.xlabel('alpha')
plt.ylabel('RMSE')
plt.ylim([0.85, 0.9]);

# %% [markdown]
# ### Check the ratio of skew observation located between -2*std ~ 2*std

# %%
ex_obs_dict = pickle.load(open('./data/obs_skew_130_330.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['1.30', '1.55', '1.80', '2.05', '2.30', '2.55', '2.80', '3.05', '3.30'])

# %%
nrows = len(ex_obs_dict.keys())
fig, axs = plt.subplots(nrows=nrows, figsize=(5, 20), sharex=True)

for i, (key, obs) in enumerate(ex_obs_dict.items()):
    obserr = (obs - X_nature[:,::8]).ravel()
    axs[i].hist(obserr)
    
    std = np.sqrt(2)
    axs[i].vlines([2*std, -2*std], ymin=0, ymax=2500, ls='dashed')
    axs[i].set_xlim([-4, 6])
    axs[i].set_title(f'alpha = {key}')
    
    total_size = obserr.size
    within_size = obserr[np.where((obserr <= 2*std) & (obserr >= -2*std))].size
    ratio = within_size / total_size
    axs[i].text(-1, 175, f'ratio={ratio:.2f}', fontsize=13)

plt.tight_layout()

# %% [markdown]
# # Fourth moment

# %% [markdown]
# ### Assimilate kurtosis observation based on normality test

# %%
ex_obs_dict = pickle.load(open('./data/obs_kurtosis_050_220.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.5', '0.6', '0.7', '0.8', '0.9', '1.2', '1.6', '1.8', '2.0', '2.2'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_d in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_d]
    
    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'delta={ex_d}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_d)
    
# CNTL
plt.plot(ts, rmse_ekf, color='k', label='CNTL')
    
# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# delta=0.5, Mean RMSE=0.8566, Variance RMSE=0.0324,  Without spinup: Mean RMSE=0.8463, Variance RMSE=0.0255
# delta=0.6, Mean RMSE=0.8895, Variance RMSE=0.0259,  Without spinup: Mean RMSE=0.8835, Variance RMSE=0.0197
# delta=0.7, Mean RMSE=0.8847, Variance RMSE=0.0285,  Without spinup: Mean RMSE=0.8734, Variance RMSE=0.0184
# delta=0.8, Mean RMSE=0.8990, Variance RMSE=0.0214,  Without spinup: Mean RMSE=0.8916, Variance RMSE=0.0138
# delta=0.9, Mean RMSE=0.8639, Variance RMSE=0.0239,  Without spinup: Mean RMSE=0.8518, Variance RMSE=0.0146
# delta=1.2, Mean RMSE=0.8722, Variance RMSE=0.0190,  Without spinup: Mean RMSE=0.8644, Variance RMSE=0.0123
# delta=1.6, Mean RMSE=0.8674, Variance RMSE=0.0248,  Without spinup: Mean RMSE=0.8527, Variance RMSE=0.0112
# delta=1.8, Mean RMSE=0.8767, Variance RMSE=0.0222,  Without spinup: Mean RMSE=0.8684, Variance RMSE=0.0151
# delta=2.0, Mean RMSE=0.8843, Variance RMSE=0.0173,  Without spinup: Mean RMSE=0.8765, Variance RMSE=0.0116
# delta=2.2, Mean RMSE=0.8846, Variance RMSE=0.0176,  Without spinup: Mean RMSE=0.8749, Variance RMSE=0.0095

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_delta = list(map(lambda s: float(s), ex_obs_dict.keys()))
xticks = np.arange(min(ex_delta), max(ex_delta), 0.2)

axs[0].plot(ex_delta, mean_rmse, '.-', label='with spinup period')
axs[0].plot(ex_delta, mean_rmse_nospn, '.-', label='without spinup period')
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(xticks)
axs[0].set_xlabel('delta')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_delta, var_rmse, '.-', label='with spinup period')
axs[1].plot(ex_delta, var_rmse_nospn, '.-', label='without spinup period')
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(xticks)
axs[1].set_xlabel('delta')
axs[1].set_ylabel('RMSE');

# %%
import seaborn as sns

fig, ax = plt.subplots()

for key in ex_obs_dict.keys():
    obs = ex_obs_dict[key]
    obserr = obs - X_nature[:,::8]
    obserr = obserr.ravel()
    sns.kdeplot(obserr, label=key, ax=ax)
plt.xlim([-20, 20])
# Out:
# (-20, 20)

# %% [markdown]
# ### Assimilate kurtosis observation with more extreme delta

# %%
ex_obs_dict = pickle.load(open('./data/obs_kurtosis_010_340.pickle', 'rb'))
ex_obs_dict.keys()
# Out:
# dict_keys(['0.1', '0.2', '0.3', '0.4', '2.5', '2.8', '3.1', '3.4'])

# %%
mean_rmse = []        # mean RMSE
mean_rmse_nospn = []  # mean RMSE without spin up periods
var_rmse = []
var_rmse_nospn = []

plt.figure(figsize=(12, 6))

for ex_d in ex_obs_dict.keys():
    obs = ex_obs_dict[ex_d]
    
    params = {
        'X_ini': X_ini,
        'obs': obs,
        'obs_interv': 8,
        'Pb': Pb,
        'R': R,
        'H_func': lambda arr: arr,
        'H': np.eye(ndim),
        'M': lambda X: M(X.ravel(), dt, F),
        'alpha': 0.3,
        'inflat': 1.4
    }
    ekf = ExtendedKF(lorenz96_fdm, dt)
    ekf.set_params(**params)
    ekf.cycle()

    # calculate RMSE and stable index
    rmse = RMSE(ekf.analysis, X_nature)
    print(
        f'delta={ex_d}, Mean RMSE={rmse.mean():.4f}, Variance RMSE={rmse.var():.4f},  '
        + f'Without spinup: Mean RMSE={rmse[50:].mean():.4f}, Variance RMSE={rmse[50:].var():.4f}'
    )
    mean_rmse.append(rmse.mean())
    mean_rmse_nospn.append(rmse[50:].mean())
    var_rmse.append(rmse.var())
    var_rmse_nospn.append(rmse[50:].var())

    plt.plot(ts, rmse, label=ex_d)
    
# CNTL
plt.plot(ts, rmse_ekf, color='k', label='CNTL')
    
# no DA
forecast = lorenz96_fdm(X_ini, ts)
rmse_noda = RMSE(forecast, X_nature)
plt.plot(ts, rmse_noda, label='NoDA', color='k', ls='dotted', alpha=0.4)
    
ax = plt.gca()
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('RMSE')
plt.xlabel('Time')
plt.ylabel('rmse');
# Out:
# delta=0.1, Mean RMSE=0.4792, Variance RMSE=0.3685,  Without spinup: Mean RMSE=0.4515, Variance RMSE=0.3237
# delta=0.2, Mean RMSE=0.8254, Variance RMSE=0.2414,  Without spinup: Mean RMSE=0.8177, Variance RMSE=0.2347
# delta=0.3, Mean RMSE=0.7688, Variance RMSE=0.0626,  Without spinup: Mean RMSE=0.7567, Variance RMSE=0.0503
# delta=0.4, Mean RMSE=0.8549, Variance RMSE=0.0410,  Without spinup: Mean RMSE=0.8470, Variance RMSE=0.0352
# delta=2.5, Mean RMSE=0.8833, Variance RMSE=0.0207,  Without spinup: Mean RMSE=0.8731, Variance RMSE=0.0127
# delta=2.8, Mean RMSE=0.8849, Variance RMSE=0.0186,  Without spinup: Mean RMSE=0.8754, Variance RMSE=0.0109
# delta=3.1, Mean RMSE=0.8892, Variance RMSE=0.0161,  Without spinup: Mean RMSE=0.8799, Variance RMSE=0.0094
# delta=3.4, Mean RMSE=0.8910, Variance RMSE=0.0165,  Without spinup: Mean RMSE=0.8826, Variance RMSE=0.0120

# %%
fig, axs = plt.subplots(ncols=2, figsize=(15, 4))

ex_delta = list(map(lambda s: float(s), ex_obs_dict.keys()))
xticks = np.arange(min(ex_delta), max(ex_delta), 0.2)

axs[0].plot(ex_delta[:4], mean_rmse[:4], 'b.-', alpha=0.6, label='with spinup period')
axs[0].plot(ex_delta[4:], mean_rmse[4:], 'b.-', alpha=0.6)
axs[0].plot(ex_delta[:4], mean_rmse_nospn[:4], 'g.-', alpha=0.6, label='without spinup period')
axs[0].plot(ex_delta[4:], mean_rmse_nospn[4:], 'g.-', alpha=0.6)
axs[0].legend()
axs[0].set_title('RMSE Mean')
axs[0].set_xticks(xticks)
axs[0].set_xlabel('delta')
axs[0].set_ylabel('RMSE')

axs[1].plot(ex_delta[:4], var_rmse[:4], 'b.-', alpha=0.6, label='with spinup period')
axs[1].plot(ex_delta[4:], var_rmse[4:], 'b.-', alpha=0.6)
axs[1].plot(ex_delta[:4], var_rmse_nospn[:4], 'g.-', alpha=0.6, label='without spinup period')
axs[1].plot(ex_delta[4:], var_rmse_nospn[4:], 'g.-', alpha=0.6)
axs[1].legend()
axs[1].set_title('RMSE Variance')
axs[1].set_xticks(xticks)
axs[1].set_xlabel('delta')
axs[1].set_ylabel('RMSE');

# %%
fig, ax = plt.subplots()

for key in ex_obs_dict.keys():
    obs = ex_obs_dict[key]
    obserr = obs - X_nature[:,::8]
    obserr = obserr.ravel()
    sns.kdeplot(obserr, label=key, ax=ax)
plt.xlim([-20, 20]);
